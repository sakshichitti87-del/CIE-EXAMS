# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             NaN          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          NaN     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#perform eda
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# sepal_length    6
# sepal_width     6
# petal_length    6
# petal_width     9
# species         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  144 non-null    float64
#  1   sepal_width   144 non-null    float64
#  2   petal_length  144 non-null    float64
#  3   petal_width   141 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    144.000000   144.000000    144.000000   141.000000
# mean       5.888889     3.037500      3.853472     1.260993
# std        0.811983     0.427527      1.736684     0.744482
# min        4.400000     2.000000      1.000000     0.100000
# 25%        5.200000     2.800000      1.600000     0.400000
# 50%        5.800000     3.000000      4.400000     1.400000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           NaN          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          NaN  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Find the missing values
df.isnull().sum()
# Out:
# sepal_length    6
# sepal_width     6
# petal_length    6
# petal_width     9
# species         0
# dtype: int64

# %%
#find the total number of species and visualise
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/iris.csv")
df['species'].value_counts()
sns.countplot(x='species',data=df)
plt.show()

# %%
#Write the code to comparing sepal length and sepal width
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/iris.csv")
sns.scatterplot(x='sepal_length',y='sepal_width',data=df)
plt.title("comparision between sepal length and sepal width")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.show()
